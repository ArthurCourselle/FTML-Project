# %% [markdown]
# # Application of unsupervised learning

# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

from datasets import load_dataset

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, adjusted_rand_score

# %% [markdown]
# ## Spotify Tracks Dataset
#
# The dataset contains audio feature data from Spotify for a large number of tracks across 125 different musical genres. Each entry includes various characteristics of a song. For instancee, we can find a song's tempo, danceability, energy, and more along with metadata like the artist, album, track name, and genre.
#
# These features are automatically generated by Spotify's internal audio analysis tools, providing a detailed, quantitative description of each track’s musical attributes. This dataset allows for a data-driven exploration of music, moving beyond user-generated tags or opinions.
#
# **Source:**
# [Spotify Tracks Dataset on HuggingFace](https://huggingface.co/datasets/maharshipandya/spotify-tracks-dataset)
#
#
# ## Problem Statement
#
# In this project, we aim to explore whether it is possible to uncover meaningful groupings of songs based solely on their audio characteristics, without using any genre labels during training. Particularly, the goal is to see if we can find genres in the clusters generated through unsupervised learning. If that is not the case we will try to analyse cluster to see what they represent.
#
# Such an approach can have several useful applications:
# - Music recommendation systems
# - Automatic playlist generation
# - Discovering new or emerging genres
# - Organizing massive music libraries
#
#
# ## Selected Features
#
# To focus purely on the musical content of each track, we will drop metadata such as artist name or album and retain only the **numeric audio features**. These features describe the composition and acoustic properties of a track.
#
# Here are the selected features and their meanings:
#
# - **danceability**: Float [0.0–1.0]
#   Indicates how suitable a track is for dancing, based on tempo, rhythm stability, beat strength, etc.
#
# - **energy**: Float [0.0–1.0]
#   Represents the intensity and activity level of the track.
#
# - **key**: Integer [0–11]
#   The estimated musical key.
#
# - **loudness**: Float (in dB)
#   The overall loudness of the track.
#
# - **mode**: Binary (0 = minor, 1 = major)
#   Indicates whether the track is in a major or minor scale.
#
# - **speechiness**: Float [0.0–1.0]
#   Detects the presence of spoken words in the track.
#
# - **acousticness**: Float [0.0–1.0]
#   Measures confidence that the track is acoustic.
#
# - **instrumentalness**: Float [0.0–1.0]
#   Predicts the likelihood that a track contains no vocals.
#
# - **liveness**: Float [0.0–1.0]
#   Estimates whether the track was recorded in front of an audience.
#
# - **valence**: Float [0.0–1.0]
#   Describes the musical "positiveness" conveyed by the track.
#
# - **tempo**: Float (BPM)
#   The speed of the track in beats per minute.
#
# - **duration_ms**: Integer (milliseconds)
#   The duration of the track.
#
# - **time_signature**: Integer [3–7]
#   Estimated number of beats per measure.
#
#   - **explicit**: Bool
#   Wether or not a song contains curse words.

# %% [markdown]
# # Data Preprocessing
#
# Before applying any unsupervised learning techniques, we need to prepare and clean the data:

# %%
ds = load_dataset("maharshipandya/spotify-tracks-dataset")["train"]

df = pd.DataFrame(ds)

print("initial shape:", df.shape)
df.head(1)
# Out:
# initial shape: (114000, 21)
#    Unnamed: 0                track_id      artists album_name track_name  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV  Gen Hoshino     Comedy     Comedy
#
#    popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 0          73       230666     False         0.676   0.461  ...    -6.746
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0        0.143        0.0322          0.000001     0.358    0.715
#
#     tempo  time_signature  track_genre
# 0  87.917               4     acoustic
#
# [1 rows x 21 columns]

# %% [markdown]
# ###  Drop Unnecessary Columns + Keep Relevant Features
#
# In the rest oif the code we will use numeric_df_without_genre (to train) and numeric_df to visualise, analyse and compare with clusters with genres.

# %%
df = df.drop(columns=['Unnamed: 0'])
le2 = LabelEncoder()
le = LabelEncoder()
numeric_df = df.select_dtypes(include=['number'])

numeric_df = df.drop(columns=['track_id', 'artists', 'album_name', 'track_name', 'popularity', 'key', 'time_signature'])
numeric_df['explicit'] = le2.fit_transform(df['explicit'])
numeric_df['track_genre'] = le.fit_transform(df['track_genre'])

numeric_df.head(1)

numeric_df_without_genre = numeric_df.drop(columns=['track_genre'])

# %% [markdown]
# # Exploratory Data Analysis and Structure of the data

# %% [markdown]
# ### Distribution of features

# %%
cols =  numeric_df.columns
numeric_df[cols].hist(bins=30, figsize=(12, 8))
plt.suptitle("Features distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis of the correlation matrix
# Here, the objective is to see whether of not some caracterstics align on the same musical dimension

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_df.corr(), cmap='coolwarm', annot=True)
plt.title("Correlation matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Popularity**
#
# The distribution is biased toward lower values, suggesting that the dataset contains many less known or rarely played tracks.
# There is no strong correlation between popularity and any other variable. This suggests that popularity is largely independent of audio features.
#
# **Loudness, Energy, Acousticness, and Instrumentalness**
#
# Loudness is strongly correlated with:
#
# - Energy (0.76): energetic tracks tend to be louder.
#
# - Acousticness (-0.59) and Instrumentalness (-0.43): those tracks are typically softer.
#
# Loud tracks are generally energetic, not acoustic, and rarely instrumental. The later is interesting since there is a lot of eletronic songs, this is a dataset bias that we explain later.
#
# **Danceability**
#
# Danceability is positively correlated with:
#
# - Valence (0.48): happy songs tend to be more danceable.
#
# - Loudness (0.26) and Energy (0.26): danceable music is usually louder and more energetic.
#
# Danceable songs tend to be happy, energetic, and loud.
#
# **Speechiness**
#
# Speechiness is correlated with:
#
# - Explicit (0.31): tracks with more spoken content are more likely to contain explicit lyrics.
#
# - Liveness (0.21): live recordings may include spoken segments or interactions with the audience.
#
# Speechy tracks are more likely to be explicit and performed live.
#
#
# **Mode and Key**
#
# Both show very low or no correlation with other features.
#
# Mode is weakly correlated with Acousticness (0.10), this might be caused by minor keys. It is interesting that there is no correlation with the Valence.
# Key appears to have no meaningful relationship with other features and could be discarded.
#
# These features might be useless.
#
# **Tempo**
#
# Tempo correlates with Energy (0.25) and Valence (0.13)
#
# Faster tracks tend to be more energetic and a bit positive.
#
# Also, Tempo values equal to zero likely represent invalid or missing data and should be removed.
#
# **Time Signature**
#
# This feature shows very low variance, with a strong dominance of 4/4 time and very few instances of 3/4.
#
# All values are in x/4 format meaning there is no representation of compound meters such as 6/8 or 9/8.
#
# Time signature does not capture complex rythme (ternary,...) and provides no discriminative power. We could remove it.
#
# **Track Genre**
#
# The genre distribution appears relatively balanced across classes.
# There are no strong correlations between genre and other features, which is expected for a well balanced classification task.
# It suggests that genres in the dataset are not trivially predictable and reflects realistic musical complexity.

# %% [markdown]
# # Contraints imposed by the problem
#
# When doing this execice, we realised that in order to be able to read the graphs we plot we could not keep all genres. Instead of merging different genres into one and therefore adding personal bias into the problem we decided to select *n* random genres to answer the problem.

# %%
# seed for reproducibility
random.seed(42)

all_genres = numeric_df['track_genre'].unique()
print(f"Total genres: {len(all_genres)}")

n_genres_to_keep = 8
selected_genres = random.sample(list(all_genres), n_genres_to_keep)

print(f"Genres after random selection ({len(selected_genres)}):")
for i, genre in enumerate(selected_genres, 1):
    print(f"{i:2d}. {genre}")

lenOld = len(numeric_df)
numeric_df = numeric_df[numeric_df['track_genre'].isin(selected_genres)]
print(f"\n{len(numeric_df)} points (out of {lenOld} initial)")

numeric_df_without_genre = numeric_df.drop(columns=['track_genre'])
# Out:
# Total genres: 8
# Genres after random selection (8):
#  1. 14
#  2. 3
#  3. 35
#  4. 17
#  5. 94
#  6. 80
#  7. 31
#  8. 28
#
# 8000 points (out of 8000 initial)

# %% [markdown]
# ### Dimensional reduction with PCA and visualisation
#
# We now reduce the data’s dimensionality not to evaluate clustering, but to assess how well the genre structure aligns with the reduced 2D representation.
# The goal is to see whether the data naturally forms groups, and whether those groups align with the genres of the songs.
#
# To evaluate how well the songs separate into meaningful groups, we use the Silhouette Score.
#
# - The Silhouette Score measures how similar each point is to its own cluster compared to other clusters.
#
# - It ranges from -1 (bad clustering) to 1 (well-separated clusters).
#
# - A value close to 0 indicates overlapping or ambiguous clusters.
#
# We are coloring points by their true genre labels to visualize the PCA. But PCA itself is unsupervised, it doesn't use the genre labels to create the axes.
#
# Later, when we apply unsupervised clustering algorithms, we will also compute silhouette scores on the predicted clusters to compare their quality and relevance.

# %%
#PCA -> sensitive to scales
# making sure all features contribute equally
scaler = StandardScaler()
X_scaled = scaler.fit_transform(numeric_df_without_genre)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

df_pca['Genre'] = numeric_df['track_genre'].values

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='Genre', palette='Set2', s=50, alpha=0.7)
plt.title("Projection PCA des morceaux filtrés (colorés par genre)")
plt.grid(True)
plt.tight_layout()
plt.show()

le = LabelEncoder()
labels = le.fit_transform(df_pca['Genre'])

score = silhouette_score(X_pca, labels)
print(f"Silhouette Score (with genres as labels) : {score:.4f}")

print(f"Explained variance ratio (PC1): {pca.explained_variance_ratio_[0]:.4f}")
print(f"Explained variance ratio (PC2): {pca.explained_variance_ratio_[1]:.4f}")
total_var = pca.explained_variance_ratio_.sum()
print(f"Total variance explained by 2 PCs: {total_var:.4f}")
# Out:
# Silhouette Score (with genres as labels) : -0.1111
# Explained variance ratio (PC1): 0.2064
# Explained variance ratio (PC2): 0.1508
# Total variance explained by 2 PCs: 0.3572

# %% [markdown]
# ### Analysis
#
# One of the first thing that jumps to mind when seeing this graph is the the lack of direct obvious graphic cluster. There is no clean visual limitation between different section of point rather a big blob of point.
#
# Secondly, we notice that the silhouette score is rather low with `-0.1111`. Meaning that on average songs are closer to samples from other genres than to their own. This suggests that the genres do not form clearly separated clusters in the PCA 2D space.
#
# To contextulize, the silhouette score is defined using two quantities:
#
# - **a(i)**: the average distance between a point *i* and all other points in the **same** cluster.
# - **b(i)**: the average distance between point *i* and all points in the **nearest** different cluster.
#
# Then the **silhouette score** for a point *i* is calculated as: $s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}$
# When projected into 2D, many distances flatten or overlap, causing small differences between *a(i)* and *b(i)* or even worse clustering than expected → negative scores
#
# PCA is a method to reduce dimensions designed to capture variance and not necessarily notice cluster separability but we still considered it to be an intereting point. This score can be a **baseline** for comparison with unsupervised clustering results later on.
#
# Variance represents how much of the data's structure (spread) is preserved in 2D. Here we notice that, we are capturing only ~36% of the original feature variance in 2 components is relatively low. So, when we plot in 2D for visualization, we are losing 64% of the variance. The information to keep from this is that **we shouldn't overinterpret the PCA plot** as it looses most of the data's complexity.

# %% [markdown]
# # Clustering
#
# ### K-Means Clustering
#
# We will start by using a K-means clustering algorithm for its simplicity and interpretability.  Just as PCA gave us a visual baseline, KMeans gives us a clustering baseline. Later, we can compare its performance against more advanced or non-linear clustering algorithms. And most importantly, the goal here is to see whether our data naturally falls into spherical, equally sized groupings (which we will see through the silhouette scores and graph itself).

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(numeric_df_without_genre)

sil_scores = []
k_values = range(2, 11)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    sil_scores.append(score)

plt.figure(figsize=(8, 4))
plt.plot(k_values, sil_scores, marker='o')
plt.xticks(k_values)
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for different numbers of KMeans clusters")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Analysis on most optimal number of clusters
#
# If our clustering followed genres, we could have expected the best silhouette score to be at k = 8 (because track_genre has 8 genres selected), but the best score was at k = 2.
#
# k = 2 often gets the highest score because it's easy to split data into two broad and well-separated clusters. As we increase k, clusters get smaller and closer together, which lowers the silhouette score, especially if the data doesn’t naturally fall into that many distinct blobs. We can note that apart from k=2 the other highest silhouette score fall k=8 (which was the expected value if our data clustered right into the genres).
#
# Overall, we can't conclude from this clustering that unsupervised clustering through K-Means doesn't directly fall into genres even if it leaves clues of it.
#
# ### Plot k=2 and analyse the average value of features for each cluster
#
# Since k=2 got the best score, we are going to plot those clusters and see if there is coorelation on some features through heatmaps.

# %%
def plot_kmeans_clusters(X_scaled, k, random_state=42):
    kmeans = KMeans(n_clusters=k, random_state=random_state)
    labels = kmeans.fit_predict(X_scaled)

    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_scaled)

    centers_pca = pca.transform(kmeans.cluster_centers_)

    plt.figure(figsize=(10, 7))
    sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=labels, palette='tab10', s=50, alpha=0.7)
    plt.scatter(centers_pca[:, 0], centers_pca[:, 1], c='black', s=200, marker='X', label='Centroids')
    plt.title(f"KMeans Clustering (k={k}) - PCA 2D Projection")
    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

plot_kmeans_clusters(X_scaled, 2, random_state=42)

# %% [markdown]
# On the plot we can clearly see the 2 different clusters. The black X marks shows the cluster centroids, which are well-separated despite some natural overlap between clusters in the transition zone. Both clusters show roughly circular distributions with similar densities, demonstrating effective data partitioning.

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
labels = kmeans.fit_predict(X_scaled)

clustered_df = numeric_df_without_genre.copy()
clustered_df['Cluster'] = labels

cluster_means = clustered_df.groupby('Cluster').mean()

# transpose juste pour le visu
cluster_means_T = cluster_means.T

plt.figure(figsize=(10, 6))
sns.heatmap(cluster_means_T, annot=True, fmt=".2f", cmap="YlGnBu", cbar=True)
plt.title("Average Feature Values per Cluster (k=2)")
plt.xlabel("Cluster")
plt.ylabel("Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis on Features for K-Means (2 Clusters)
#
# Based on the average feature values heatmap, we can identify distinct characteristics between the two clusters:
#
# **Cluster 0** shows higher values for:
# - `acousticness` (0.58 vs 0.17) - significantly more acoustic
# - `mode` (0.73 vs 0.59) - more major keys
# - `speechiness` (0.11 vs 0.08) - slightly more speech-like
# - `instrumentalness` (0.10 vs 0.08) - slightly more instrumental
#
# **Cluster 1** shows higher values for:
# - `duration_ms` (205,926 vs 170,650) - longer tracks
# - `energy` (0.76 vs 0.41) - much higher energy
# - `loudness` (-5.48 vs -10.63) - significantly louder
# - `tempo` (129.18 vs 115.78) - faster tempo
# - `liveness` (0.22 vs 0.16) - more live recordings
# - `valence` (0.52 vs 0.49) - slightly more positive
#
# Features with minimal differences:
# - `explicit`, `danceability` - relatively similar across clusters
#
#
# ### **Cluster 0 = "Acoustic, Calm" Songs**
# - Higher **acousticness** and **instrumentalness**
# - Lower **energy**, **loudness**, and **tempo**
# - Shorter duration, more **major keys**
# - Likely contains **acoustic**, **folk**, or **ambient** genres
#
# ### **Cluster 1 = "Energetic, Electronic" Songs**
# - Much higher **energy**, **loudness**, and **tempo**
# - Longer duration, more **live** recordings
# - Higher **valence** (more positive/upbeat)
# - Likely contains **pop**, **dance**, **rock**, or **electronic** genres

# %% [markdown]
# ### Plotting for k=8
#
# We can plot for K-means with *k=8* to check wether or not the K-means algorithms can find the genres through its clusters.
#
# After plotting we can clearly see that the centroids are too close together and that the different clusters overlap way too much to say that k=8 finds good clusters.

# %%
plot_kmeans_clusters(X_scaled, 8, random_state=42)

# %% [markdown]
# #  Gaussian Mixture Model (GMM)
#
# KMeans assumes hard boundaries and equal-sized, spherical clusters. GMM allows soft clustering (probabilistic membership) and elliptical cluster shapes, which can better model real-world data like music features, where boundaries between genres are fuzzy.

# %%
sil_scores = []
k_values = range(2, 11)

for k in k_values:
    gmm = GaussianMixture(n_components=k, random_state=42)
    cluster_labels = gmm.fit_predict(X_scaled)
    
    sil = silhouette_score(X_scaled, cluster_labels)
    
    sil_scores.append(sil)

plt.figure(figsize=(10, 4))
plt.plot(k_values, sil_scores, marker='o', label='Silhouette Score')
plt.xlabel("Number of clusters (k)")
plt.ylabel("Score")
plt.title("GMM Clustering Evaluation")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis
#
# The plot of Silhouette score for GMM shows a distinctive pattern with k=2 achieving the highest score of approximately 0.175. The scores then drop significantly to around 0.073 for k=3 and k=4 and overall stays there untul it start going down after k=8.
#
# Why is k = 2 often the best once again?
# When the structure of the data is not clearly separable into many compact clusters, both KMeans and GMM tend to find a broad high-level separation, for example, splitting tracks into “energetic” vs. “calm,” or “acoustic” vs. “electronic” and easily split the datapoints into 2 clusters (like we have seen with K-Means). A silhouette score rewards cohesion and separation, which is easiest to achieve with just 2 well-separated groups, even if those don’t align with meaningful genres.

# %%
def plot_gmm_clusters(X_scaled, k, random_state=42):
    gmm = GaussianMixture(n_components=k, random_state=random_state)
    labels = gmm.fit_predict(X_scaled)

    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_scaled)

    means_pca = pca.transform(gmm.means_)

    plt.figure(figsize=(10, 7))
    sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=labels, palette='tab10', s=50, alpha=0.7)
    plt.scatter(means_pca[:, 0], means_pca[:, 1], c='black', s=200, marker='X', label='GMM Centers')
    plt.title(f"GMM Clustering (k={k}) - PCA 2D Projection")
    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

plot_gmm_clusters(X_scaled, 2, random_state=42)

# %% [markdown]
# The GMM clustering visualization show a different pattern compared to K-Means. Unlike K-Means which showed spatially separated clusters, GMM shows significant overlap between the two clusters, with centers positioned very close together in the central region of the data distribution.
#
# This extensive overlap suggests that GMM is modeling the data as two overlapping Gaussian distributions rather than finding distinct boundaries. While this may better represent the probabilistic nature of the underlying data structure, it results in less clear-cut cluster assignments and explains why the visual separation appears less "clean" than the K-Means approach.

# %%
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_labels = gmm.fit_predict(X_scaled)

clustered_df = numeric_df_without_genre.copy()
clustered_df['Cluster'] = gmm_labels

cluster_means = clustered_df.groupby('Cluster').mean()

cluster_means_T = cluster_means.T

plt.figure(figsize=(10, 6))
sns.heatmap(cluster_means_T, annot=True, fmt=".2f", cmap="YlGnBu", cbar=True)
plt.title("Average Feature Values per Cluster (GMM, k=2)")
plt.xlabel("Cluster")
plt.ylabel("Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis on Features for GMM (2 Clusters)
#
# Based on the average feature values heatmap, the clusters show these characteristics:
#
# ### Features with **Notable Differences**:
#
# **Cluster 0** shows higher values for:
# - `explicit` (1.00 vs 0.00) - exclusively explicit content
# - `danceability` (0.68 vs 0.63) - slightly more danceable
# - `speechiness` (0.13 vs 0.08) - more speech-like content
# - `duration_ms` (176,747 vs 197,388) - slightly shorter duration
#
# **Cluster 1** shows higher values for:
# - `duration_ms` (197,388 vs 176,747) - longer tracks
# - `energy` (0.65 vs 0.62) - slightly higher energy
# - `mode` (0.64 vs 0.60) - more major keys
# - `acousticness` (0.30 vs 0.25) - slightly more acoustic
# - `instrumentalness` (0.09 vs 0.04) - more instrumental
# - `valence` (0.52 vs 0.47) - more positive/upbeat
#
# ### Features with **Minimal Differences**:
# - `loudness`, `liveness`, `tempo` - very similar across clusters
#
# ## Interpretation
#
# ### **Cluster 0 = "Explicit, Speech-Heavy" Songs**
# - **100% explicit** content (major distinguishing factor)
# - Higher **speechiness** and **danceability**
# - **Shorter** duration tracks
# - Likely genres: **Hip-Hop**, **Rap**, **explicit Pop**
#
# ### **Cluster 1 = "Clean, Longer, Instrumental" Songs**
# - **No explicit** content
# - **Longer** duration, higher **valence** and **energy**
# - More **acoustic** and **instrumental**
# - Likely genres: **Pop**, **Rock**, **Acoustic**, **Instrumental**

# %% [markdown]
# ### Plotting for 8 components
#
# We can check to see if we plot the GMM with 8 being the number of components there really isn't any clear clusters visible meaning that we can't find the genres from the features with GMM. The GMM centers are way too close together and from that results a lot of overlapping

# %%
plot_gmm_clusters(X_scaled, 8, random_state=42)

# %% [markdown]
# ## Comparison of results on features with K-Means and GMM
#
# | Feature             | K-Means Cluster 0 ↑ | GMM Cluster 0 ↑ | Comment |
# |---------------------|---------------------|------------------|---------|
# | `explicit`          | ❌ (0.16)           | ✅ (1.00)        | **Different**: GMM Cluster 0 = 100% explicit |
# | `speechiness`       | ✅ (0.11)           | ✅ (0.13)        | Both: More speech in Cluster 0 |
# | `danceability`      | ✅ (0.68)           | ✅ (0.68)        | Both: More danceable |
# | `acousticness`      | ✅ (0.58)           | ❌ (0.25)        | **Different**: K-Means Cluster 0 more acoustic |
# | `mode`              | ✅ (0.73)           | ❌ (0.60)        | **Different**: K-Means Cluster 0 more major keys |
# | `instrumentalness`  | ✅ (0.10)           | ❌ (0.04)        | **Different**: K-Means Cluster 0 more instrumental |
# | `energy`            | ❌ (0.41)           | ❌ (0.62)        | Both: Cluster 1 more energetic |
# | `loudness`          | ❌ (-10.63)         | ❌ (-7.20)       | Both: Cluster 1 louder |
# | `tempo`             | ❌ (115.78)         | ❌ (123.86)      | Both: Cluster 1 faster |
# | `valence`           | ❌ (0.49)           | ❌ (0.47)        | Both: Cluster 1 more positive |
# | `duration_ms`       | ✅ (170,650)        | ❌ (176,747)     | **Different**: K-Means Cluster 0 shorter |
#
#
#
# ## Conclusion
#
# **K-Means and GMM produce fundamentally different clustering results:**
#
# ### K-Means Clusters:
# - **Cluster 0**: "Acoustic, Calm" - higher acousticness, instrumentalness, shorter duration
# - **Cluster 1**: "Energetic, Electronic" - higher energy, loudness, tempo, longer duration
#
# ### GMM Clusters:
# - **Cluster 0**: "Explicit, Speech-Heavy" - 100% explicit content, more speechiness
# - **Cluster 1**: "Clean, Energetic" - no explicit content, higher energy, longer duration
#
# ### Key Differences:
# 1. **Primary separation criteria**: K-Means focuses on acoustic vs. energetic characteristics, while GMM separates based on explicit content
# 2. **Feature priorities**: The algorithms identify different distinguishing features as most important
# 3. **Cluster interpretations**: Completely different musical categories emerge
#
# This **disagreement** between methods suggests that the underlying data structure may not have a single clear clustering solution, and that different algorithms can reveal different aspects of the data's organization. The choice between explicit content (GMM) vs. acoustic characteristics (K-Means) as the primary separator indicates the complexity of music categorization from these features.
